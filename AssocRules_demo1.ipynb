# %% [markdown]
# ## Aprendizaje de reglas de asociación

# %% [markdown]
# Objetivos:
#
#     derivar reglas de la forma {A} -> {B}

# %%
import numpy as np
from itertools import combinations, groupby
from collections import Counter

# %% [markdown]
# order 1:  **apple, egg, milk**   -->  item pairs: {apple, egg}, {apple, milk}, {egg, milk}
#
# order 2:  **egg, milk**          -->  item pairs: {egg, milk}

# %%
# Sample data
orders = np.array([[1,'apple'], [1,'egg'], [1,'milk'], [2,'egg'], [2,'milk']], dtype=object)

# Generator that yields item pairs, one at a time
def get_item_pairs(order_item):
    
    # For each order, generate a list of items in that order
    for order_id, order_object in groupby(orders, lambda x: x[0]):
        item_list = [item[1] for item in order_object]      
    
        # For each item list, generate item pairs, one at a time
        for item_pair in combinations(item_list, 2):
            yield item_pair

# %%
orders
# Out:
# array([[1, 'apple'],
#        [1, 'egg'],
#        [1, 'milk'],
#        [2, 'egg'],
#        [2, 'milk']], dtype=object)

# %% [markdown]
# Lo primero que necesitamos es contar el numero de veces que aparece cada par de items:

# %%
Counter(get_item_pairs(orders))
# Out:
# Counter({('apple', 'egg'): 1, ('apple', 'milk'): 1, ('egg', 'milk'): 2})

# %% [markdown]
# ### Analisis de los datos de *instacart*

# %%
import pandas as pd
import numpy as np
import sys
from itertools import combinations, groupby
from collections import Counter
from IPython.display import display

# %%
def size(obj):
    return "{0:.2f} MB".format(sys.getsizeof(obj) / (1000 * 1000))

# %% [markdown]
# Descripcion de los datos:
#
# `orders` (3.4m rows, 206k users):
# * `order_id`: order identifier
# * `user_id`: customer identifier
# * `eval_set`: which evaluation set this order belongs in (see `SET` described below)
# * `order_number`: the order sequence number for this user (1 = first, n = nth)
# * `order_dow`: the day of the week the order was placed on
# * `order_hour_of_day`: the hour of the day the order was placed on
# * `days_since_prior`: days since the last order, capped at 30 (with NAs for `order_number` = 1)
#
# `products` (50k rows):
# * `product_id`: product identifier
# * `product_name`: name of the product
# * `aisle_id`: foreign key
# * `department_id`: foreign key
#
# `aisles` (134 rows):
# * `aisle_id`: aisle identifier
# * `aisle`: the name of the aisle
#
# `deptartments` (21 rows):
# * `department_id`: department identifier
# * `department`: the name of the department
#
# `order_products__SET` (30m+ rows):
# * `order_id`: foreign key
# * `product_id`: foreign key
# * `add_to_cart_order`: order in which each product was added to cart
# * `reordered`: 1 if this product has been ordered by this user in the past, 0 otherwise
#
# where `SET` is one of the four following evaluation sets (`eval_set` in `orders`):
# * `"prior"`: orders prior to that users most recent order (~3.2m orders)
# * `"train"`: training data supplied to participants (~131k orders)
# * `"test"`: test data reserved for machine learning competitions (~75k orders)

# %%
orders = pd.read_csv('instacart_2017_05_01/order_products__prior_short.csv')
print('orders -- dimensions: {0};   size: {1}'.format(orders.shape, size(orders)))
display(orders.head())
# Out:
# orders -- dimensions: (999, 4);   size: 0.00 MB
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Convert from DataFrame to a Series, with order_id as index and item_id as value
orders = orders.set_index('order_id')['product_id'].rename('item_id')
display(orders.head(10))
type(orders)
# Out:
# order_id
# 2    33120
# 2    28985
# 2     9327
# 2    45918
# 2    30035
# 2    17794
# 2    40141
# 2     1819
# 2    43668
# 3    33754
# Name: item_id, dtype: int64
# pandas.core.series.Series

# %%
print('dimensions: {0};   size: {1};   unique_orders: {2};   unique_items: {3}'
      .format(orders.shape, size(orders), len(orders.index.unique()), len(orders.value_counts())))
# Out:
# dimensions: (999,);   size: 0.00 MB;   unique_orders: 103;   unique_items: 809

# %%
# Returns frequency counts for items and item pairs
def freq(iterable):
    if type(iterable) == pd.core.series.Series:
        return iterable.value_counts().rename("freq")
    else: 
        return pd.Series(Counter(iterable)).rename("freq")

    
# Returns number of unique orders
def order_count(order_item):
    return len(set(order_item.index))


# Returns generator that yields item pairs, one at a time
def get_item_pairs(order_item):
    order_item = order_item.reset_index().as_matrix()
    for order_id, order_object in groupby(order_item, lambda x: x[0]):
        item_list = [item[1] for item in order_object]
              
        for item_pair in combinations(item_list, 2):
            yield item_pair
            

# Returns frequency and support associated with item
def merge_item_stats(item_pairs, item_stats):
    return (item_pairs
                .merge(item_stats.rename(columns={'freq': 'freqA', 'support': 'supportA'}), left_on='item_A', right_index=True)
                .merge(item_stats.rename(columns={'freq': 'freqB', 'support': 'supportB'}), left_on='item_B', right_index=True))


# Returns name associated with item
def merge_item_name(rules, item_name):
    columns = ['itemA','itemB','freqAB','supportAB','freqA','supportA','freqB','supportB', 
               'confidenceAtoB','confidenceBtoA','lift']
    rules = (rules
                .merge(item_name.rename(columns={'item_name': 'itemA'}), left_on='item_A', right_on='item_id')
                .merge(item_name.rename(columns={'item_name': 'itemB'}), left_on='item_B', right_on='item_id'))
    return rules[columns]

# %%
def association_rules(order_item, min_support):

    print("Starting order_item: {:22d}".format(len(order_item)))


    # Calculate item frequency and support
    item_stats             = freq(order_item).to_frame("freq")
    item_stats['support']  = item_stats['freq'] / order_count(order_item) * 100


    # Filter from order_item items below min support 
    qualifying_items       = item_stats[item_stats['support'] >= min_support].index
    order_item             = order_item[order_item.isin(qualifying_items)]

    print("Items with support >= {}: {:15d}".format(min_support, len(qualifying_items)))
    print("Remaining order_item: {:21d}".format(len(order_item)))


    # Filter from order_item orders with less than 2 items
    order_size             = freq(order_item.index)
    qualifying_orders      = order_size[order_size >= 2].index
    order_item             = order_item[order_item.index.isin(qualifying_orders)]

    print("Remaining orders with 2+ items: {:11d}".format(len(qualifying_orders)))
    print("Remaining order_item: {:21d}".format(len(order_item)))


    # Recalculate item frequency and support
    item_stats             = freq(order_item).to_frame("freq")
    item_stats['support']  = item_stats['freq'] / order_count(order_item) * 100


    # Get item pairs generator
    item_pair_gen          = get_item_pairs(order_item)


    # Calculate item pair frequency and support
    item_pairs              = freq(item_pair_gen).to_frame("freqAB")
    item_pairs['supportAB'] = item_pairs['freqAB'] / len(qualifying_orders) * 100

    print("Item pairs: {:31d}".format(len(item_pairs)))


    # Filter from item_pairs those below min support
    item_pairs              = item_pairs[item_pairs['supportAB'] >= min_support]

    print("Item pairs with support >= {}: {:10d}\n".format(min_support, len(item_pairs)))


    # Create table of association rules and compute relevant metrics
    item_pairs = item_pairs.reset_index().rename(columns={'level_0': 'item_A', 'level_1': 'item_B'})
    item_pairs = merge_item_stats(item_pairs, item_stats)
    
    item_pairs['confidenceAtoB'] = item_pairs['supportAB'] / item_pairs['supportA']
    item_pairs['confidenceBtoA'] = item_pairs['supportAB'] / item_pairs['supportB']
    item_pairs['lift']           = item_pairs['supportAB'] / (item_pairs['supportA'] * item_pairs['supportB'])
    
    
    # Return association rules sorted by lift in descending order
    return item_pairs.sort_values('lift', ascending=False)

# %%
# %%time
rules = association_rules(orders, 0.01)
# Out:
# Starting order_item:                    999
# Items with support >= 0.01:             809
# Remaining order_item:                   999
# Remaining orders with 2+ items:         100
# Remaining order_item:                   996
# Item pairs:                            6628
# Item pairs with support >= 0.01:       6628
#
# CPU times: user 52 ms, sys: 8 ms, total: 60 ms
# Wall time: 58.1 ms

# %%
item_name   = pd.read_csv('instacart_2017_05_01/products.csv')
item_name   = item_name.rename(columns={'product_id':'item_id', 'product_name':'item_name'})
rules_final = merge_item_name(rules, item_name).sort_values('lift', ascending=False)
display(rules_final)
# Out:
#                                                   itemA  \
# 0                        Organic Mini Homestyle Waffles
# 3645                    Organic Strawberry Fruit Spread
# 3656                                      Salted Butter
# 3655                    Organic Strawberry Fruit Spread
# 3654                         Whole Organic Omega 3 Milk
# 3653                            Large Greenhouse Tomato
# 3647                        Cultured Low Fat Buttermilk
# 3646                                      Salted Butter
# 3644                         Whole Organic Omega 3 Milk
# 3227                                 Orange Bell Pepper
# 3643                            Large Greenhouse Tomato
# 3636                       Organic Heavy Whipping Cream
# 3635                        Cultured Low Fat Buttermilk
# 3634                                      Salted Butter
# 3633                    Organic Strawberry Fruit Spread
# 3632                         Whole Organic Omega 3 Milk
# 3657                        Cultured Low Fat Buttermilk
# 3658                       Organic Heavy Whipping Cream
# 3659                                     1% Lowfat Milk
# 3666                            Large Greenhouse Tomato
# 3667                         Whole Organic Omega 3 Milk
# 3668                    Organic Strawberry Fruit Spread
# 3669                                      Salted Butter
# 3670                        Cultured Low Fat Buttermilk
# 3671                       Organic Heavy Whipping Cream
# 3672                                     1% Lowfat Milk
# 3673  Organic Whole Milk Strawberry Beet Berry Yogur...
# 3680                            Large Greenhouse Tomato
# 3681                    Organic Strawberry Fruit Spread
# 3682                                      Salted Butter
# ...                                                 ...
# 986                                         Raspberries
# 916                              Bag of Organic Bananas
# 2453                             Bag of Organic Bananas
# 82                               Bag of Organic Bananas
# 2445                             Bag of Organic Bananas
# 4226                             Bag of Organic Bananas
# 6431                             Bag of Organic Bananas
# 900                              Bag of Organic Bananas
# 665                                 Organic Raspberries
# 666                                         Large Lemon
# 2636                               Organic Hass Avocado
# 3758                               Organic Strawberries
# 937                                              Banana
# 2638                                    Organic Avocado
# 4834                             Bag of Organic Bananas
# 987                                       Organic Lemon
# 3604                             Bag of Organic Bananas
# 3973                             Bag of Organic Bananas
# 3326                                             Banana
# 2422                                        Large Lemon
# 2475                               Organic Hass Avocado
# 3759                               Organic Baby Spinach
# 988                                 Organic Raspberries
# 668                                Organic Baby Spinach
# 2423                               Organic Strawberries
# 3760                                             Banana
# 3761                             Bag of Organic Bananas
# 2477                                             Banana
# 2424                               Organic Baby Spinach
# 671                              Bag of Organic Bananas
#
#                                                   itemB  freqAB  supportAB  \
# 0                              Naturals Chicken Nuggets       1        1.0
# 3645                       Organic Heavy Whipping Cream       1        1.0
# 3656  Organic Whole Milk Strawberry Beet Berry Yogur...       1        1.0
# 3655  Organic Whole Milk Strawberry Beet Berry Yogur...       1        1.0
# 3654  Organic Whole Milk Strawberry Beet Berry Yogur...       1        1.0
# 3653  Organic Whole Milk Strawberry Beet Berry Yogur...       1        1.0
# 3647                       Organic Heavy Whipping Cream       1        1.0
# 3646                       Organic Heavy Whipping Cream       1        1.0
# 3644                       Organic Heavy Whipping Cream       1        1.0
# 3227                               Marinara Pasta Sauce       1        1.0
# 3643                       Organic Heavy Whipping Cream       1        1.0
# 3636                                     1% Lowfat Milk       1        1.0
# 3635                                     1% Lowfat Milk       1        1.0
# 3634                                     1% Lowfat Milk       1        1.0
# 3633                                     1% Lowfat Milk       1        1.0
# 3632                                     1% Lowfat Milk       1        1.0
# 3657  Organic Whole Milk Strawberry Beet Berry Yogur...       1        1.0
# 3658  Organic Whole Milk Strawberry Beet Berry Yogur...       1        1.0
# 3659  Organic Whole Milk Strawberry Beet Berry Yogur...       1        1.0
# 3666                                 Organic Black Plum       1        1.0
# 3667                                 Organic Black Plum       1        1.0
# 3668                                 Organic Black Plum       1        1.0
# 3669                                 Organic Black Plum       1        1.0
# 3670                                 Organic Black Plum       1        1.0
# 3671                                 Organic Black Plum       1        1.0
# 3672                                 Organic Black Plum       1        1.0
# 3673                                 Organic Black Plum       1        1.0
# 3680                         Whole Organic Omega 3 Milk       1        1.0
# 3681                         Whole Organic Omega 3 Milk       1        1.0
# 3682                         Whole Organic Omega 3 Milk       1        1.0
# ...                                                 ...     ...        ...
# 986                              Bag of Organic Bananas       1        1.0
# 916                                 Large Alfresco Eggs       1        1.0
# 2453                                 Organic Fuji Apple       1        1.0
# 82                                  Organic Gala Apples       1        1.0
# 2445                                      Yellow Onions       1        1.0
# 4226                                2% Reduced Fat Milk       1        1.0
# 6431                                         Whole Milk       1        1.0
# 900                                    Organic Cucumber       1        1.0
# 665                                     Organic Avocado       1        1.0
# 666                                     Organic Avocado       1        1.0
# 2636                               Organic Strawberries       1        1.0
# 3758                               Organic Hass Avocado       1        1.0
# 937                                       Organic Lemon       1        1.0
# 2638                               Organic Strawberries       1        1.0
# 4834                               Organic Baby Carrots       1        1.0
# 987                              Bag of Organic Bananas       1        1.0
# 3604                                     Cucumber Kirby       1        1.0
# 3973                               Organic Blackberries       1        1.0
# 3326                                        Large Lemon       1        1.0
# 2422                                             Banana       1        1.0
# 2475                               Organic Baby Spinach       1        1.0
# 3759                               Organic Hass Avocado       1        1.0
# 988                              Bag of Organic Bananas       1        1.0
# 668                                     Organic Avocado       1        1.0
# 2423                                             Banana       1        1.0
# 3760                               Organic Hass Avocado       1        1.0
# 3761                               Organic Hass Avocado       1        1.0
# 2477                               Organic Baby Spinach       1        1.0
# 2424                                             Banana       1        1.0
# 671                                     Organic Avocado       1        1.0
#
#       freqA  supportA  freqB  supportB  confidenceAtoB  confidenceBtoA  \
# 0         1       1.0      1       1.0        1.000000        1.000000
# 3645      1       1.0      1       1.0        1.000000        1.000000
# 3656      1       1.0      1       1.0        1.000000        1.000000
# 3655      1       1.0      1       1.0        1.000000        1.000000
# 3654      1       1.0      1       1.0        1.000000        1.000000
# 3653      1       1.0      1       1.0        1.000000        1.000000
# 3647      1       1.0      1       1.0        1.000000        1.000000
# 3646      1       1.0      1       1.0        1.000000        1.000000
# 3644      1       1.0      1       1.0        1.000000        1.000000
# 3227      1       1.0      1       1.0        1.000000        1.000000
# 3643      1       1.0      1       1.0        1.000000        1.000000
# 3636      1       1.0      1       1.0        1.000000        1.000000
# 3635      1       1.0      1       1.0        1.000000        1.000000
# 3634      1       1.0      1       1.0        1.000000        1.000000
# 3633      1       1.0      1       1.0        1.000000        1.000000
# 3632      1       1.0      1       1.0        1.000000        1.000000
# 3657      1       1.0      1       1.0        1.000000        1.000000
# 3658      1       1.0      1       1.0        1.000000        1.000000
# 3659      1       1.0      1       1.0        1.000000        1.000000
# 3666      1       1.0      1       1.0        1.000000        1.000000
# 3667      1       1.0      1       1.0        1.000000        1.000000
# 3668      1       1.0      1       1.0        1.000000        1.000000
# 3669      1       1.0      1       1.0        1.000000        1.000000
# 3670      1       1.0      1       1.0        1.000000        1.000000
# 3671      1       1.0      1       1.0        1.000000        1.000000
# 3672      1       1.0      1       1.0        1.000000        1.000000
# 3673      1       1.0      1       1.0        1.000000        1.000000
# 3680      1       1.0      1       1.0        1.000000        1.000000
# 3681      1       1.0      1       1.0        1.000000        1.000000
# 3682      1       1.0      1       1.0        1.000000        1.000000
# ...     ...       ...    ...       ...             ...             ...
# 986       3       3.0     12      12.0        0.333333        0.083333
# 916      12      12.0      3       3.0        0.083333        0.333333
# 2453     12      12.0      3       3.0        0.083333        0.333333
# 82       12      12.0      3       3.0        0.083333        0.333333
# 2445     12      12.0      3       3.0        0.083333        0.333333
# 4226     12      12.0      3       3.0        0.083333        0.333333
# 6431     12      12.0      3       3.0        0.083333        0.333333
# 900      12      12.0      3       3.0        0.083333        0.333333
# 665       5       5.0      8       8.0        0.200000        0.125000
# 666       5       5.0      8       8.0        0.200000        0.125000
# 2636      7       7.0      6       6.0        0.142857        0.166667
# 3758      6       6.0      7       7.0        0.166667        0.142857
# 937      11      11.0      4       4.0        0.090909        0.250000
# 2638      8       8.0      6       6.0        0.125000        0.166667
# 4834     12      12.0      4       4.0        0.083333        0.250000
# 987       4       4.0     12      12.0        0.250000        0.083333
# 3604     12      12.0      4       4.0        0.083333        0.250000
# 3973     12      12.0      4       4.0        0.083333        0.250000
# 3326     11      11.0      5       5.0        0.090909        0.200000
# 2422      5       5.0     11      11.0        0.200000        0.090909
# 2475      7       7.0      8       8.0        0.142857        0.125000
# 3759      8       8.0      7       7.0        0.125000        0.142857
# 988       5       5.0     12      12.0        0.200000        0.083333
# 668       8       8.0      8       8.0        0.125000        0.125000
# 2423      6       6.0     11      11.0        0.166667        0.090909
# 3760     11      11.0      7       7.0        0.090909        0.142857
# 3761     12      12.0      7       7.0        0.083333        0.142857
# 2477     11      11.0      8       8.0        0.090909        0.125000
# 2424      8       8.0     11      11.0        0.125000        0.090909
# 671      12      12.0      8       8.0        0.083333        0.125000
#
#           lift
# 0     1.000000
# 3645  1.000000
# 3656  1.000000
# 3655  1.000000
# 3654  1.000000
# 3653  1.000000
# 3647  1.000000
# 3646  1.000000
# 3644  1.000000
# 3227  1.000000
# 3643  1.000000
# 3636  1.000000
# 3635  1.000000
# 3634  1.000000
# 3633  1.000000
# 3632  1.000000
# 3657  1.000000
# 3658  1.000000
# 3659  1.000000
# 3666  1.000000
# 3667  1.000000
# 3668  1.000000
# 3669  1.000000
# 3670  1.000000
# 3671  1.000000
# 3672  1.000000
# 3673  1.000000
# 3680  1.000000
# 3681  1.000000
# 3682  1.000000
# ...        ...
# 986   0.027778
# 916   0.027778
# 2453  0.027778
# 82    0.027778
# 2445  0.027778
# 4226  0.027778
# 6431  0.027778
# 900   0.027778
# 665   0.025000
# 666   0.025000
# 2636  0.023810
# 3758  0.023810
# 937   0.022727
# 2638  0.020833
# 4834  0.020833
# 987   0.020833
# 3604  0.020833
# 3973  0.020833
# 3326  0.018182
# 2422  0.018182
# 2475  0.017857
# 3759  0.017857
# 988   0.016667
# 668   0.015625
# 2423  0.015152
# 3760  0.012987
# 3761  0.011905
# 2477  0.011364
# 2424  0.011364
# 671   0.010417
#
# [6628 rows x 11 columns]
